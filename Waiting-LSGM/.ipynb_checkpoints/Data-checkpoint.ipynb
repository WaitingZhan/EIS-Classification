# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import glob
from matplotlib import pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# %%
#build an empty matrix to save frequency
freqency_matrix=[]
real_matrix=[]
imaginary_matrix=[]
Time_matrix=[]

# %%
#build a matrix to save time,frequency,Real Resistance,imaginary Resistance
number_file=0
path ='*.txt'
files=glob.glob(path)
for file in files:
    print(file)
    number_file=number_file+1
    df = pd.read_csv(file,skiprows=18,sep='\s+')
    time=pd.read_csv(file)
    myList = []
    with open(file) as fp:
        for i in range(7):
            line=fp.readline()
            if i==0:
                myList.append(line[27:])
            if i==6:
                myList.append(line[25:])
    freqency=df.iloc[:,1]
    real=df.iloc[:,2]
    imaginary=df.iloc[:,3]
    freqency_matrix.append(freqency)
    real_matrix.append(real)
    imaginary_matrix.append(imaginary)
    Time_matrix.append(myList)
# Out:
# 500-eis-3_-ocv.txt
# 500-eis-50_-210-5.txt
# 500-eis-3_-ocv-7.txt
# 500-eis-3_-ocv-6.txt
# 500-eis-50_-210-4.txt
# 500-eis-50_-co-2-300ma.txt
# it-co-soec-7-120ma.txt
# it-co-soec-4-400ma.txt
# 500-eis-50_-210-1.txt
# 500-eis-50_-210-3.txt
# 500-eis-50_-210-2.txt
# 500-eis-50_-co-4-0ma.txt
# 500-eis-50_-co-8-ocv.txt
# it-co-soec-1.txt
# it-co-soec-6-120ma.txt
# it-co-soec-5-400ma.txt
# 500-eis-50_-co-7-120ma.txt
# 500-eis-50_-co-4-400ma.txt
# 500-eis-50_-ocv.txt
# it-co-soec-2-300ma.txt
# it-co-soec-8-120ma.txt
# 500-eis-50_-co-1.txt
# 500-eis-50_-co-1-120ma.txt
# 500-eis-50_-ocv-5.txt
# 500-eis-50_-ocv-4.txt
# 500-eis-3_-ocv-10.txt
# 500-eis-50_-co-6-120ma.txt
# 500-eis-50_-co-5-400ma.txt
# 500-eis-50_-ocv-3.txt
# 500-eis-50_-ocv-2.txt
# it-co-soec-3-0ma.txt
# 500-eis-3_-ocv-8.txt
# 500-eis-3_-ocv-9.txt
# 500-eis-50_-ocv-1.txt

# %%
Time_matrix
# Out:
# [['v - MAY,04.2015\n', '10:47:20\n'],
#  ['10-5 - MAY,07.2015\n', '10:08:11\n'],
#  ['v-7 - MAY,08.2015\n', '17:31:20\n'],
#  ['v-6 - MAY,08.2015\n', '09:44:26\n'],
#  ['10-4 - MAY,06.2015\n', '16:43:28\n'],
#  ['o-2-300ma - MAY,11.2015\n', '17:14:57\n'],
#  ['ec-7-120ma - MAY,12.2015\n', '22 - 14:01:12\n'],
#  ['ec-4-400ma - MAY,11.2015\n', '47 - 21:13:56\n'],
#  ['10-1 - MAY,05.2015\n', '09:31:37\n'],
#  ['10-3 - MAY,06.2015\n', '09:29:24\n'],
#  ['10-2 - MAY,05.2015\n', '20:19:23\n'],
#  ['o-4-0ma - MAY,11.2015\n', '19:05:21\n'],
#  ['o-8 - MAY,12.2015\n', '23:00:00\n'],
#  ['ec-1 - MAY,11.2015\n', '58 - 16:03:58\n'],
#  ['ec-6-120ma - MAY,12.2015\n', '35 - 09:53:22\n'],
#  ['ec-5-400ma - MAY,11.2015\n', '24 - 22:30:42\n'],
#  ['o-7-120ma - MAY,12.2015\n', '14:05:37\n'],
#  ['o-4-400ma - MAY,11.2015\n', '21:17:42\n'],
#  ['cv - MAY,04.2015\n', '10:53:50\n'],
#  ['ec-2-300ma - MAY,11.2015\n', '19 - 17:11:10\n'],
#  ['ec-8-120ma - MAY,12.2015\n', '44 - 14:47:55\n'],
#  ['o-1 - MAY,11.2015\n', '14:47:47\n'],
#  ['o-1-120ma - MAY,11.2015\n', '16:08:07\n'],
#  ['cv-5 - MAY,07.2015\n', '09:52:10\n'],
#  ['cv-4 - MAY,06.2015\n', '16:39:53\n'],
#  ['v-10 - MAY,11.2015\n', '09:41:35\n'],
#  ['o-6-120ma - MAY,12.2015\n', '09:59:40\n'],
#  ['o-5-400ma - MAY,11.2015\n', '22:34:18\n'],
#  ['cv-3 - MAY,06.2015\n', '09:24:40\n'],
#  ['cv-2 - MAY,05.2015\n', '20:12:24\n'],
#  ['ec-3-0ma - MAY,11.2015\n', '06 - 19:01:43\n'],
#  ['v-8 - MAY,09.2015\n', '11:46:04\n'],
#  ['v-9 - MAY,10.2015\n', '22:01:34\n'],
#  ['cv-1 - MAY,05.2015\n', '09:24:55\n']]

# %%
number_file
# Out:
# 34

# %%
imaginary_matrix[1]
# Out:
# 0     0.402350
# 1     0.302080
# 2     0.220660
# 3     0.156030
# 4     0.104410
# 5     0.061559
# 6     0.027017
# 7    -0.001382
# 8    -0.024345
# 9    -0.044160
# 10   -0.060461
# 11   -0.074045
# 12   -0.085339
# 13   -0.094515
# 14   -0.101360
# 15   -0.106820
# 16   -0.109830
# 17   -0.112590
# 18   -0.113250
# 19   -0.111850
# 20   -0.109720
# 21   -0.106800
# 22   -0.102860
# 23   -0.099464
# 24   -0.096050
# 25   -0.089601
# 26   -0.089187
# 27   -0.086491
# 28   -0.085060
# 29   -0.084164
# 30   -0.084852
# 31   -0.083268
# 32   -0.086466
# 33   -0.084756
# 34   -0.091277
# 35   -0.098271
# 36   -0.100500
# 37   -0.102880
# 38   -0.103570
# 39   -0.110600
# 40   -0.113320
# 41   -0.111750
# 42   -0.109550
# 43   -0.106670
# 44   -0.104630
# 45   -0.090197
# 46   -0.114150
# 47   -0.080192
# 48   -0.041827
# 49   -0.052136
# 50    0.064962
# 51    0.097851
# 52    0.093552
# Name: R/Ohm, dtype: float64

# %%
# 3-d plot

# %%
fig = plt.figure()
ax = Axes3D(fig)

for i in range(1, number_file):
    X = freqency_matrix[i]
    Y = real_matrix[i]
    Z = imaginary_matrix[i]
    for c, m, zlow, zhigh in [('r', 'o', -50, -25), ('b', '^', -30, -5)]:
        ax.scatter(X,Y,Z, c=(0.01*i, 1/i, 0.04/i), marker=m)

ax.set_xlabel('freqency')
ax.set_ylabel('real resistance')
ax.set_zlabel('imaginary resistance')

plt.show()
